# %%
from nba_api.stats.static import teams

nba_teams = teams.get_teams()

nuggets = [team for team in nba_teams if team['abbreviation'] == 'DEN'][0]
nuggets_id = nuggets['id']
print(f'nuggets_id: {nuggets_id}')
# Out:
# nuggets_id: 1610612743

# %%
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.library.parameters import Season
from nba_api.stats.library.parameters import SeasonType

gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=nuggets_id,
                            season_nullable=Season.default,
                            season_type_nullable=SeasonType.regular)  

games_dict = gamefinder.get_normalized_dict()
games = games_dict['LeagueGameFinderResults']
game = games[0]
game_id = game['GAME_ID']
game_matchup = game['MATCHUP']

print(f'Searching through {len(games)} game(s) for the game_id of {game_id} where {game_matchup}')
# Out:
# Searching through 21 game(s) for the game_id of 0022000341 where DEN @ LAL

# %%
from nba_api.stats.endpoints import playbyplay
df = playbyplay.PlayByPlay(game_id).get_data_frames()[0]
df.head(500)
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0    0022000341         2            12                   0       1
# 1    0022000341         4            10                   0       1
# 2    0022000341         7             1                   1       1
# 3    0022000341         9             6                   1       1
# 4    0022000341        11             1                  80       1
# ..          ...       ...           ...                 ...     ...
# 454  0022000341       670             2                   1       4
# 455  0022000341       671             4                   0       4
# 456  0022000341       666             2                   5       4
# 457  0022000341       668             4                   0       4
# 458  0022000341       669            13                   0       4
#
#     WCTIMESTRING PCTIMESTRING                           HOMEDESCRIPTION  \
# 0       10:21 PM        12:00                                      None
# ...

# %%
import pandas as pd

# %%
teams = ['Los Angeles Lakers', 'Denver Nuggets']
spread = ['-5 (-110)', '+5 (+110)']
moneyline = ['-220', '+185']
over_under = ['Over 219.5 -110', 'Under 219.5 -110']

# %%
gambling_df = pd.DataFrame(columns=[teams, spread, moneyline, over_under])
gambling_df
# Out:
# Empty DataFrame
# Columns: [(Los Angeles Lakers, -5 (-110), -220, Over 219.5 -110), (Denver Nuggets, +5 (+110), +185, Under 219.5 -110)]
# Index: []
